# %% [markdown]
# <a href="https://colab.research.google.com/github/VadimFilips/ProjectFilipsGit/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
input_string = input("Введите строку: ")
string_without_spaces = input_string.replace(" ", "")
char_count = len(string_without_spaces)
print(f"Количество символов без учета пробелов: {char_count}")
# Out:
# Введите строку: Hello World
# Количество символов без учета пробелов: 10
